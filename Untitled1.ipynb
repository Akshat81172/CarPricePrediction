# %%
import numpy as np
import pandas as pd

# %%
df= pd.read_excel("C:\\Users\\aksha\\Desktop\\Practice\\dataset\\quikr_car.xlsx")

# %%
df
# Out:
#                                        name    company  year          Price  \
# 0      Hyundai Santro Xing XO eRLX Euro III    Hyundai  2007          80000
# 1                   Mahindra Jeep CL550 MDI   Mahindra  2006       4,25,000
# 2                Maruti Suzuki Alto 800 Vxi     Maruti  2018  Ask For Price
# 3    Hyundai Grand i10 Magna 1.2 Kappa VTVT    Hyundai  2014       3,25,000
# 4          Ford EcoSport Titanium 1.5L TDCi       Ford  2014       5,75,000
# ..                                      ...        ...   ...            ...
# 887                                      Ta       Tara  zest       3,10,000
# 888                     Tata Zest XM Diesel       Tata  2018       2,60,000
# 889                      Mahindra Quanto C8   Mahindra  2013       3,90,000
# 890                Honda Amaze 1.2 E i VTEC      Honda  2014       1,80,000
# 891               Chevrolet Sail 1.2 LT ABS  Chevrolet  2014       1,60,000
#
#      kms_driven fuel_type
# 0    45,000 kms    Petrol
# ...

# %%
df.shape
# Out:
# (892, 6)

# %%
df.columns
# Out:
# Index(['name', 'company', 'year', 'Price', 'kms_driven', 'fuel_type'], dtype='object')

# %%
df.isnull().sum()
# Out:
# name           0
# company        0
# year           0
# Price          0
# kms_driven    52
# fuel_type     55
# dtype: int64

# %%
df['name'].unique()
# Out:
# array(['Hyundai Santro Xing XO eRLX Euro III', 'Mahindra Jeep CL550 MDI',
#        'Maruti Suzuki Alto 800 Vxi',
#        'Hyundai Grand i10 Magna 1.2 Kappa VTVT',
#        'Ford EcoSport Titanium 1.5L TDCi', 'Ford Figo', 'Hyundai Eon',
#        'Ford EcoSport Ambiente 1.5L TDCi',
#        'Maruti Suzuki Alto K10 VXi AMT', 'Skoda Fabia Classic 1.2 MPI',
#        'Maruti Suzuki Stingray VXi', 'Hyundai Elite i20 Magna 1.2',
#        'Mahindra Scorpio SLE BS IV', 'Audi A8', 'Audi Q7',
#        'Mahindra Scorpio S10', 'Maruti Suzuki Alto 800',
#        'Hyundai i20 Sportz 1.2', 'Maruti Suzuki Alto 800 Lx',
#        'Maruti Suzuki Vitara Brezza ZDi', 'Maruti Suzuki Alto LX',
#        'Mahindra Bolero DI', 'Maruti Suzuki Swift Dzire ZDi',
#        'Mahindra Scorpio S10 4WD', 'Maruti Suzuki Swift Vdi BSIII',
#        'Maruti Suzuki Wagon R VXi BS III',
#        'Maruti Suzuki Wagon R VXi Minor',
#        'Toyota Innova 2.0 G 8 STR BS IV', 'Renault Lodgy 85 PS RXL',
# ...

# %%
df['company'].unique()
# Out:
# array(['Hyundai', 'Mahindra', 'Maruti', 'Ford', 'Skoda', 'Audi', 'Toyota',
#        'Renault', 'Honda', 'Datsun', 'Mitsubishi', 'Tata', 'Volkswagen',
#        'I', 'Chevrolet', 'Mini', 'BMW', 'Nissan', 'Hindustan', 'Fiat',
#        'Commercial', 'MARUTI', 'Force', 'Mercedes', 'Land', 'Yamaha',
#        'selling', 'URJENT', 'Swift', 'Used', 'Jaguar', 'Jeep', 'tata',
#        'Sale', 'very', 'Volvo', 'i', 2012, 'Well', 'all', 7, 9, 'scratch',
#        'urgent', 'sell', 'TATA', 'Any', 'Tara'], dtype=object)

# %%
df['year'].unique()
# Out:
# array([2007, 2006, 2018, 2014, 2015, 2012, 2013, 2016, 2010, 2017, 2008,
#        2011, 2019, 2009, 2005, 2000, '...', '150k', 'TOUR', 2003, 'r 15',
#        2004, 'Zest', '/-Rs', 'sale', 1995, 'ara)', 2002, 'SELL', 2001,
#        'tion', 'odel', '2 bs', 'arry', 'Eon', 'o...', 'ture', 'emi',
#        'car', 'able', 'no.', 'd...', 'SALE', 'digo', 'sell', 'd Ex',
#        'n...', 'e...', 'D...', ', Ac', 'go .', 'k...', 'o c4', 'zire',
#        'cent', 'Sumo', 'cab', 't xe', 'EV2', 'r...', 'zest'], dtype=object)

# %%
df['Price'].unique()
# Out:
# array([80000, '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', 75000, '1,00,000', '2,90,000',
#        95000, '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000', 85000,
#        '2,00,000', '5,70,000', '1,10,000', '4,48,999', '18,91,111',
#        '1,59,500', '3,44,999', '4,49,999', '8,65,000', '6,99,000',
#        '3,75,000', '2,24,999', '12,00,000', '1,95,000', '3,51,000',
#        '2,40,000', 90000, '1,55,000', '6,00,000', '1,89,500', '2,10,000',
#        '3,90,000', '1,35,000', '16,00,000', '7,01,000', '2,65,000',
#        '5,25,000', '3,72,000', '6,35,000', '5,50,000', '4,85,000',
# ...

# %%
df['kms_driven'].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
df['fuel_type'].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        892 non-null    object
#  1   company     892 non-null    object
#  2   year        892 non-null    object
#  3   Price       892 non-null    object
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: object(6)
# memory usage: 41.9+ KB

# %% [markdown]
# ## Data cleaning

# %%
df['name']=df['name'].str.split().str.slice(start=0,stop=3).str.join(' ')

# %%
df=df.reset_index(drop=True)

# %%
df
# Out:
#                        name    company  year          Price  kms_driven  \
# 0       Hyundai Santro Xing    Hyundai  2007          80000  45,000 kms
# 1       Mahindra Jeep CL550   Mahindra  2006       4,25,000      40 kms
# 2        Maruti Suzuki Alto     Maruti  2018  Ask For Price  22,000 kms
# 3         Hyundai Grand i10    Hyundai  2014       3,25,000  28,000 kms
# 4    Ford EcoSport Titanium       Ford  2014       5,75,000  36,000 kms
# ..                      ...        ...   ...            ...         ...
# 887                      Ta       Tara  zest       3,10,000         NaN
# 888            Tata Zest XM       Tata  2018       2,60,000  27,000 kms
# 889      Mahindra Quanto C8   Mahindra  2013       3,90,000  40,000 kms
# 890         Honda Amaze 1.2      Honda  2014       1,80,000      Petrol
# 891      Chevrolet Sail 1.2  Chevrolet  2014       1,60,000      Petrol
#
#     fuel_type
# 0      Petrol
# 1      Diesel
# 2      Petrol
# 3      Petrol
# 4      Diesel
# ...

# %%
df['year'] = pd.to_numeric(df['year'], errors='coerce')

df= df.dropna(subset=['year'])
df['year'] = df['year'].astype(int)
print(df['year'].unique())
# Out:
# [2007 2006 2018 2014 2015 2012 2013 2016 2010 2017 2008 2011 2019 2009
#  2005 2000 2003 2004 1995 2002 2001]
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\2799232437.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %%
df['year'] = df['year'].astype(int)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\1483339248.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year'] = df['year'].astype(int)

# %%
df['Price'].unique()
# Out:
# array([80000, '4,25,000', 'Ask For Price', '3,25,000', '5,75,000',
#        '1,75,000', '1,90,000', '8,30,000', '2,50,000', '1,82,000',
#        '3,15,000', '4,15,000', '3,20,000', '10,00,000', '5,00,000',
#        '3,50,000', '1,60,000', '3,10,000', 75000, '1,00,000', '2,90,000',
#        95000, '1,80,000', '3,85,000', '1,05,000', '6,50,000', '6,89,999',
#        '4,48,000', '5,49,000', '5,01,000', '4,89,999', '2,80,000',
#        '3,49,999', '2,84,999', '3,45,000', '4,99,999', '2,35,000',
#        '2,49,999', '14,75,000', '3,95,000', '2,20,000', '1,70,000', 85000,
#        '2,00,000', '5,70,000', '1,10,000', '4,48,999', '18,91,111',
#        '1,59,500', '3,44,999', '4,49,999', '8,65,000', '6,99,000',
#        '3,75,000', '2,24,999', '12,00,000', '1,95,000', '3,51,000',
#        '2,40,000', 90000, '1,55,000', '6,00,000', '1,89,500', '2,10,000',
#        '3,90,000', '1,35,000', '16,00,000', '7,01,000', '2,65,000',
#        '5,25,000', '3,72,000', '6,35,000', '5,50,000', '4,85,000',
# ...

# %%
df['Price'] = df['Price'].replace('Ask For Price', np.nan)
df['Price'] = df['Price'].replace({',': ''}, regex=True)
df['Price'] = pd.to_numeric(df['Price'], errors='coerce')
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\2677232544.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].replace('Ask For Price', np.nan)
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\2677232544.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].replace({',': ''}, regex=True)
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\2677232544.py:3: SettingWithCopyWarning:
# ...

# %%
df
# Out:
#                        name    company  year     Price    kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000.0    45,000 kms    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000.0        40 kms    Diesel
# 2        Maruti Suzuki Alto     Maruti  2018       NaN    22,000 kms    Petrol
# 3         Hyundai Grand i10    Hyundai  2014  325000.0    28,000 kms    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000.0    36,000 kms    Diesel
# ..                      ...        ...   ...       ...           ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000.0  1,32,000 kms    Petrol
# 888            Tata Zest XM       Tata  2018  260000.0    27,000 kms    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000.0    40,000 kms    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000.0        Petrol       NaN
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000.0        Petrol       NaN
#
# [842 rows x 6 columns]

# %%
df['Price'].fillna(df['Price'].mode()[0],inplace=True)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3507730017.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Price'].fillna(df['Price'].mode()[0],inplace=True)
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3507730017.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df['Price'] = df['Price'].astype(int)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\1817184942.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Price'] = df['Price'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    int64
#  4   kms_driven  840 non-null    object
#  5   fuel_type   837 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 46.0+ KB

# %%
df["kms_driven"].unique()
# Out:
# array(['45,000 kms', '40 kms', '22,000 kms', '28,000 kms', '36,000 kms',
#        '59,000 kms', '41,000 kms', '25,000 kms', '24,530 kms',
#        '60,000 kms', '30,000 kms', '32,000 kms', '48,660 kms',
#        '4,000 kms', '16,934 kms', '43,000 kms', '35,550 kms',
#        '39,522 kms', '39,000 kms', '55,000 kms', '72,000 kms',
#        '15,975 kms', '70,000 kms', '23,452 kms', '35,522 kms',
#        '48,508 kms', '15,487 kms', '82,000 kms', '20,000 kms',
#        '68,000 kms', '38,000 kms', '27,000 kms', '33,000 kms',
#        '46,000 kms', '16,000 kms', '47,000 kms', '35,000 kms',
#        '30,874 kms', '15,000 kms', '29,685 kms', '1,30,000 kms',
#        '19,000 kms', nan, '54,000 kms', '13,000 kms', '38,200 kms',
#        '50,000 kms', '13,500 kms', '3,600 kms', '45,863 kms',
#        '60,500 kms', '12,500 kms', '18,000 kms', '13,349 kms',
#        '29,000 kms', '44,000 kms', '42,000 kms', '14,000 kms',
#        '49,000 kms', '36,200 kms', '51,000 kms', '1,04,000 kms',
# ...

# %%
df['kms_driven']=df['kms_driven'].str.split().str.get(0).str.replace(',','')
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\778356149.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven']=df['kms_driven'].str.split().str.get(0).str.replace(',','')

# %%
df['kms_driven'] = df['kms_driven'].replace('Petrol','20000')
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\1283506485.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven'] = df['kms_driven'].replace('Petrol','20000')

# %%
df
# Out:
#                        name    company  year   Price kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000      45000    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000         40    Diesel
# 2        Maruti Suzuki Alto     Maruti  2018  250000      22000    Petrol
# 3         Hyundai Grand i10    Hyundai  2014  325000      28000    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000      36000    Diesel
# ..                      ...        ...   ...     ...        ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000     132000    Petrol
# 888            Tata Zest XM       Tata  2018  260000      27000    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000      40000    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000      20000       NaN
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000      20000       NaN
#
# [842 rows x 6 columns]

# %%
df['kms_driven'].fillna(10000, inplace=True)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3487284625.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['kms_driven'].fillna(10000, inplace=True)
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3487284625.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven'].fillna(10000, inplace=True)

# %%
df.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     5
# dtype: int64

# %%
df['kms_driven'] = df['kms_driven'].astype(int)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\822853482.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['kms_driven'] = df['kms_driven'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    int64
#  4   kms_driven  842 non-null    int64
#  5   fuel_type   837 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 46.0+ KB

# %%
df["fuel_type"].unique()
# Out:
# array(['Petrol', 'Diesel', nan, 'LPG'], dtype=object)

# %%
df['fuel_type'].fillna(df['fuel_type'].mode()[0],inplace=True)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3745506408.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['fuel_type'].fillna(df['fuel_type'].mode()[0],inplace=True)
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\3745506408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df
# Out:
#                        name    company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000          40    Diesel
# 2        Maruti Suzuki Alto     Maruti  2018  250000       22000    Petrol
# 3         Hyundai Grand i10    Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000       36000    Diesel
# ..                      ...        ...   ...     ...         ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM       Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000       40000    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000       20000    Petrol
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000       20000    Petrol
#
# [842 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# name          0
# company       0
# year          0
# Price         0
# kms_driven    0
# fuel_type     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    int64
#  4   kms_driven  842 non-null    int64
#  5   fuel_type   842 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 46.0+ KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 842 entries, 0 to 891
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        842 non-null    object
#  1   company     842 non-null    object
#  2   year        842 non-null    int64
#  3   Price       842 non-null    int64
#  4   kms_driven  842 non-null    int64
#  5   fuel_type   842 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 46.0+ KB

# %%
df.to_csv('Cleaned_Car_data.csv')

# %% [markdown]
# ## Data visualization

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=df['company']
y=df['Price']

# %%
plt.title('company vs Price')
plt.xlabel('company')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.bar(x,y)
# Out:
# <BarContainer object of 842 artists>

# %%
plt.title('company vs Price')
plt.xlabel('company')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.scatter(x,y,color='red')

# %%
x=df['year']
y=df['Price']
plt.title('year vs Price')
plt.xlabel('year')
plt.ylabel('Price')
plt.bar(x,y)
# Out:
# <BarContainer object of 842 artists>

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x='year', y='Price', hue='fuel_type')
plt.title('Year vs Price by Fuel Type')
plt.xlabel('Year')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
sns.barplot(data=df, x='year', y='Price', hue='fuel_type')
plt.title('Year vs Price by Fuel Type')
plt.xlabel('Year')
plt.ylabel('Price')
plt.xticks(rotation=45)
plt.grid()

# %%
plt.subplots(figsize=(15,7))
ax=sns.boxplot(x='company',y='Price',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_1452\475026656.py:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')

# %% [markdown]
# ##  Subplot with price vs year

# %%
plt.subplots(figsize=(20,10))
ax=sns.swarmplot(x='year',y='Price',data=df)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# C:\Users\aksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 15.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\aksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 30.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\aksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 31.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\aksha\anaconda3\Lib\site-packages\seaborn\categorical.py:3399: UserWarning: 36.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## price vs fuel_type

# %%
plt.subplots(figsize=(14,7))
sns.boxplot(x='fuel_type',y='Price',data=df)
# Out:
# <Axes: xlabel='fuel_type', ylabel='Price'>

# %% [markdown]
# ##  corelation

# %%
correlation_matrix = df[['year', 'kms_driven', 'Price']].corr()

sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ###  Data train test split

# %%
df
# Out:
#                        name    company  year   Price  kms_driven fuel_type
# 0       Hyundai Santro Xing    Hyundai  2007   80000       45000    Petrol
# 1       Mahindra Jeep CL550   Mahindra  2006  425000          40    Diesel
# 2        Maruti Suzuki Alto     Maruti  2018  250000       22000    Petrol
# 3         Hyundai Grand i10    Hyundai  2014  325000       28000    Petrol
# 4    Ford EcoSport Titanium       Ford  2014  575000       36000    Diesel
# ..                      ...        ...   ...     ...         ...       ...
# 886    Toyota Corolla Altis     Toyota  2009  300000      132000    Petrol
# 888            Tata Zest XM       Tata  2018  260000       27000    Diesel
# 889      Mahindra Quanto C8   Mahindra  2013  390000       40000    Diesel
# 890         Honda Amaze 1.2      Honda  2014  180000       20000    Petrol
# 891      Chevrolet Sail 1.2  Chevrolet  2014  160000       20000    Petrol
#
# [842 rows x 6 columns]

# %%
x=df[['name','company','year','kms_driven','fuel_type']]
y=df['Price']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (673, 5)
# (169, 5)
# (673,)
# (169,)

# %%
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.metrics import r2_score

# %%
oh=OneHotEncoder()
oh.fit(x[['name','company','fuel_type']])
# Out:
# OneHotEncoder()

# %%
lr=LinearRegression()

# %%
oh.categories_
# Out:
# [array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
#         'Audi A8', 'Audi Q3 2.0', 'Audi Q5 2.0', 'Audi Q7', 'BMW 3 Series',
#         'BMW 5 Series', 'BMW 7 Series', 'BMW X1', 'BMW X1 sDrive20d',
#         'BMW X1 xDrive20d', 'Chevrolet Beat', 'Chevrolet Beat Diesel',
#         'Chevrolet Beat LS', 'Chevrolet Beat LT', 'Chevrolet Beat PS',
#         'Chevrolet Cruze LTZ', 'Chevrolet Enjoy', 'Chevrolet Enjoy 1.4',
#         'Chevrolet Sail 1.2', 'Chevrolet Sail UVA', 'Chevrolet Spark',
#         'Chevrolet Spark 1.0', 'Chevrolet Spark LS', 'Chevrolet Spark LT',
#         'Chevrolet Tavera LS', 'Chevrolet Tavera Neo', 'Datsun GO T',
#         'Datsun Go Plus', 'Datsun Redi GO', 'Fiat Linea Emotion',
#         'Fiat Petra ELX', 'Fiat Punto Emotion', 'Force Motors Force',
#         'Force Motors One', 'Ford EcoSport', 'Ford EcoSport Ambiente',
#         'Ford EcoSport Titanium', 'Ford EcoSport Trend',
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(categories=oh.categories_),['name','company','fuel_type']),
                                    remainder='passthrough')

# %%
pipe=make_pipeline(column_trans,lr)

# %%
pipe.fit(x_train,y_train)
# Out:
# C:\Users\aksha\AppData\Roaming\Python\Python312\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Audi A3 Cabriolet', 'Audi A4 1.8', 'Audi A4 2.0', 'Audi A6 2.0',
# ...

# %%
import pickle

# Save the trained model
with open('carpredict.pkl', 'wb') as model_file:
    pickle.dump(pipe, model_file)

# %%
z=pipe.predict(x_test)

# %%
z
# Out:
# array([ 121249.11204939,  720955.81675334,  229071.22709225,
#         560179.55897374,  653275.67216912,  523665.96528277,
#         179026.89319285,  388350.70894651,  617533.15496405,
#         347193.73349866,   46684.11478308,  260979.3363238 ,
#         500238.87760416,  450928.6952401 ,  215296.57633687,
#        1172027.21212084,  456363.41540663,  148968.32180439,
#         183896.18666843,  472103.60157507,  409436.19466414,
#         177468.82920252,  258984.45530079,  498299.45199442,
#         657075.71104018,   69217.76019652,  413458.37418782,
#         367019.3799997 ,  467287.29757971,   76883.91727626,
#         441272.18558885,  418593.66476301,  415940.53968257,
#         373063.13331976,  238037.77559686,  224421.3910348 ,
#         554243.15782336,  367019.3799997 ,  511192.85775639,
#         426794.9215949 ,   20442.60892824,  630785.78925788,
#        -108568.45934956,  488457.16611706,  513476.46624336,
# ...

# %%
mean_absolute_error(y_test,z)
# Out:
# np.float64(179265.29375391454)

# %%
mean_squared_error(y_test,z)
# Out:
# np.float64(426580661093.3574)

# %%
r2_score(y_test,z)
# Out:
# 0.1525381602258028

# %%
scores=[]
for i in range(100):
    x_train,y_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr=LinearRegression()
    pipe=make_pipeline(column_trans,lr)
    pipe.fit(x_train,y_train)
    z=pipe.predict(x_test)
    scores.append(r2_score(y_test,z))

# %%
np.argmax(scores)
# Out:
# np.int64(42)

# %%
scores[np.argmax(scores)]
# Out:
# 0.1525381602258028

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=np.argmax(scores))
lr=LinearRegression()
pipe=make_pipeline(column_trans,lr)
pipe.fit(x_train,y_train)
z=pipe.predict(x_test)
r2_score(y_test,z)
# Out:
# 0.1525381602258028

# %%
input_values = [['Toyota Corolla Altis','Toyota',2022,20000,'Petrol']]
columns = pipe.feature_names_in_
input_data = pd.DataFrame(input_values, columns=columns)
q= pipe.predict(input_data)

# %%
q
# Out:
# array([538588.4128344])

# %%
import pickle

# %%
pickle.dump(pipe,open('carpredict.pkl','wb'))

# %%
## to load and preidct the value
#import pickle
#import pandas as pd
#z=pickle.load(open('carpredict','rb'))
#input_values = [['Maruti Suzuki Swift', 'Maruti', 2020, 1000000, 'Petrol']]
#columns = z.feature_names_in_
#input_data = pd.DataFrame(input_values, columns=columns)
#z.predict(input_data)

# %%
df['company']
# Out:
# 0        Hyundai
# 1       Mahindra
# 2         Maruti
# 3        Hyundai
# 4           Ford
#          ...
# 886       Toyota
# 888         Tata
# 889     Mahindra
# 890        Honda
# 891    Chevrolet
# Name: company, Length: 842, dtype: object
